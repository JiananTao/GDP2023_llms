# %%
import pandas as pd

# %%
df = pd.read_csv('topic_data.csv')
df
# Out:
#      Topic           Term  Term Percentage  \
# 0   Topic0          women            0.010
# 1   Topic0      pregnancy            0.008
# 2   Topic0           risk            0.008
# 3   Topic0    infertility            0.007
# 4   Topic0         review            0.007
# ..     ...            ...              ...
# 65  Topic6       outcomes            0.007
# 66  Topic6    infertility            0.007
# 67  Topic6            art            0.006
# 68  Topic6  endometriosis            0.006
# 69  Topic6         review            0.006
#
#                                     List of Sentences
# 0   ['In the last 20\xa0years, aspecific auto-immu...
# 1   ['The direct pathogenesis of this auto-immunit...
# 2   ['Meta-analysis of studies that evaluated the ...
# 3   ['On average, 10\xa0% of infertile couples hav...
# 4   ['A systematic review was performed (PUBMED) u...
# ..                                                ...
# 65  ['Also, the variation in the participant, inte...
# ...

# %%
df['first_sentence'] = df['List of Sentences'].str.split('.').str[0]

# %%
df
# Out:
#      Topic           Term  Term Percentage  \
# 0   Topic0          women            0.010
# 1   Topic0      pregnancy            0.008
# 2   Topic0           risk            0.008
# 3   Topic0    infertility            0.007
# 4   Topic0         review            0.007
# ..     ...            ...              ...
# 65  Topic6       outcomes            0.007
# 66  Topic6    infertility            0.007
# 67  Topic6            art            0.006
# 68  Topic6  endometriosis            0.006
# 69  Topic6         review            0.006
#
#                                     List of Sentences  \
# 0   ['In the last 20\xa0years, aspecific auto-immu...
# 1   ['The direct pathogenesis of this auto-immunit...
# 2   ['Meta-analysis of studies that evaluated the ...
# 3   ['On average, 10\xa0% of infertile couples hav...
# 4   ['A systematic review was performed (PUBMED) u...
# ..                                                ...
# 65  ['Also, the variation in the participant, inte...
# ...

# %%
df.to_csv('topic_data_first_sen.csv', index=False)
